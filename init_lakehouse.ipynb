# %% [markdown]
# #Selecting Catalog

# %%
# %sql
USE CATALOG databricks_lakehouse;

# %% [markdown]
# #Create lakehouse schema

# %%
# %sql
CREATE SCHEMA IF NOT EXISTS bronze
COMMENT 'Bronze layer: raw ingested data';

CREATE SCHEMA IF NOT EXISTS silver
COMMENT 'Silver layer: cleaned and transformed data';

CREATE SCHEMA IF NOT EXISTS gold
COMMENT 'Gold layer: business-ready data';

# %% [markdown]
# #Create Volume

# %%
# %sql
CREATE VOLUME IF NOT EXISTS databricks_lakehouse.bronze.raw_sources
COMMENT 'Volume for raw source files (CSV)';
