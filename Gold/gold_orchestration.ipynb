# %% [markdown]
# #Orchestration logic

# %%
gold_notebooks =[
    "./gold_dim_customers",
    "./gold_dim_products",
    "./gold_fact_sales"
]

print("Starting gold layer")
for nb in gold_notebooks:
    print(f"Running {nb}")
    dbutils.notebook.run(nb, 600)
print("Gold layer finished")
